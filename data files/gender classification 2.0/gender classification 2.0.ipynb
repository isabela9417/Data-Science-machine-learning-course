# %% [markdown]
# # **Changing the number of hidden layers in FC layers**
#
# ## 1. Loading data
# ## 2. Pre-processing the data
# ## 3. creating training and validation set
# ## 4. Defining the architecture
# ## 5. Compiling the model
# ## 6. Training the model
# ## 7. Evaluating model performance

# %%
# import necessary libraries and function

import os
from PIL import Image
import numpy as np
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.layers import Dense, InputLayer
from keras.models import Sequential
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 10
#       7 import matplotlib.pyplot as plt
#       8 get_ipython().run_line_magic('matplotlib', 'inline')
# ---> 10 from keras.layers import Dense, InputLayer
#      11 from keras.models import Sequential
#      12 from sklearn.model_selection import train_test_split
#
# File ~\anaconda3\Lib\site-packages\keras\__init__.py:10
#       7 import os
#       9 # Import everything from /api/ into keras.
# ---> 10 from keras.api import *  # noqa: F403
#      11 from keras.api import __version__  # Import * ignores names start with "_".
#      13 # Add everything in /api/ to the module search path.
#
# File ~\anaconda3\Lib\site-packages\keras\api\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
# ...

# %%
pip install opencv-python
# Out:
# ...
#
# ...

# %%
pip install imutils
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import tensorflow as tf
#       2 print(tf.__version__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\__init__.py:42
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#      41 _os.environ["TF2_BEHAVIOR"] = "1"
# ---> 42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
#      45 from tensorflow._api.v2 import __internal__
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\tf2.py:21
#       1 # Copyright 2018 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
# ...

# %%
# load all image paths
from imutils import paths
import cv2


imagePaths = list(paths.list_images("C:/Users/Annah/gender/Data-Science-machine-learning-projects/data files/gender classification 2.0"))

# %%
# check imagePaths
imagePaths
# Out:
# ['C:/Users/Annah/gender/Data-Science-machine-learning-projects/data files/gender classification 2.0\\Training\\female\\131422.jpg.jpg',
#  'C:/Users/Annah/gender/Data-Science-machine-learning-projects/data files/gender classification 2.0\\Training\\female\\131423.jpg.jpg',
#  'C:/Users/Annah/gender/Data-Science-machine-learning-projects/data files/gender classification 2.0\\Training\\female\\131425.jpg.jpg',
#  'C:/Users/Annah/gender/Data-Science-machine-learning-projects/data files/gender classification 2.0\\Training\\female\\131427.jpg.jpg',
#  'C:/Users/Annah/gender/Data-Science-machine-learning-projects/data files/gender classification 2.0\\Training\\female\\131428.jpg.jpg',
#  'C:/Users/Annah/gender/Data-Science-machine-learning-projects/data files/gender classification 2.0\\Training\\female\\131429.jpg.jpg',
#  'C:/Users/Annah/gender/Data-Science-machine-learning-projects/data files/gender classification 2.0\\Training\\female\\131432.jpg.jpg',
# ...

# %%
# display the images

for imagePath in imagePaths:
    image = cv2.imread(imagePath)
    cv2.imshow("Frame", image)
    cv2.waitKey()
cv2.destroyAllWindows()

# %%
# reading the csv file

train  = rea
