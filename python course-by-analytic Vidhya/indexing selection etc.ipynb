# %%
# importing required librries

import pandas as pd

# %%
# reading the dataset

data = pd.read_csv("test_FewQE9B.csv")

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
# selecting a column by name

data['Outlet_Size']
# Out:
# 0       Medium
# 1          NaN
# 2          NaN
# 3          NaN
# 4       Medium
#          ...
# 5676     Small
# 5677    Medium
# 5678       NaN
# 5679       NaN
# 5680       NaN
# Name: Outlet_Size, Length: 5681, dtype: object

# %%
# selecting more columns

data[['Item_Weight', 'Item_Visibility', 'Outlet_Identifier']]
# Out:
#       Item_Weight  Item_Visibility Outlet_Identifier
# 0          20.750         0.007565            OUT049
# 1           8.300         0.038428            OUT017
# 2          14.600         0.099575            OUT010
# 3           7.315         0.015388            OUT017
# 4             NaN         0.118599            OUT027
# ...           ...              ...               ...
# 5676       10.500         0.013496            OUT046
# 5677        7.600         0.142991            OUT018
# 5678       10.000         0.073529            OUT045
# 5679       15.300         0.000000            OUT017
# 5680        9.500         0.104720            OUT045
#
# [5681 rows x 3 columns]

# %%
# selecting columns by their positions

data.iloc[:6]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDW58       20.750          Low Fat         0.007565
# 1           FDW14        8.300              reg         0.038428
# 2           NCN55       14.600          Low Fat         0.099575
# 3           FDQ58        7.315          Low Fat         0.015388
# 4           FDY38          NaN          Regular         0.118599
# 5           FDH56        9.800          Regular         0.063817
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# 5  Fruits and Vegetables  117.1492            OUT046
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# ...

# %%
# selecting columns by their position
# now am selecting everything from the 1st and 2nd columns

data.iloc[:,:2]
# Out:
#      Item_Identifier  Item_Weight
# 0              FDW58       20.750
# 1              FDW14        8.300
# 2              NCN55       14.600
# 3              FDQ58        7.315
# 4              FDY38          NaN
# ...              ...          ...
# 5676           FDB58       10.500
# 5677           FDD47        7.600
# 5678           NCO17       10.000
# 5679           FDJ26       15.300
# 5680           FDU37        9.500
#
# [5681 rows x 2 columns]

# %%
# return columns position based on a condition

data[data['Item_Weight'] <= 9]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              FDW14        8.300              reg         0.038428
# 3              FDQ58        7.315          Low Fat         0.015388
# 8              FDN33        6.305          Regular         0.123365
# 9              FDA36        5.985          Low Fat         0.005698
# 11             FDQ56        6.590          Low Fat         0.105811
# ...              ...          ...              ...              ...
# 5654           FDQ57        7.275          Low Fat         0.000000
# 5659           DRK37        5.000          Low Fat         0.044073
# 5672           NCH42        6.860          Low Fat         0.036594
# 5673           FDF46        7.070          Low Fat         0.094053
# 5677           FDD47        7.600          Regular         0.142991
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 1                     Dairy   87.3198            OUT017
# ...
