# %%
# import the required libraries

import pandas as pd

# %%
# reading the dataset

data = pd.read_csv("/Users/Staff/Downloads/test_FewQE9B.csv")

# %%
# view rows either buttom or first

# view first 10
data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDW58       20.750          Low Fat         0.007565
# 1           FDW14        8.300              reg         0.038428
# 2           NCN55       14.600          Low Fat         0.099575
# 3           FDQ58        7.315          Low Fat         0.015388
# 4           FDY38          NaN          Regular         0.118599
# 5           FDH56        9.800          Regular         0.063817
# 6           FDL48       19.350          Regular         0.082602
# 7           FDC48          NaN          Low Fat         0.015782
# 8           FDN33        6.305          Regular         0.123365
# 9           FDA36        5.985          Low Fat         0.005698
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# ...

# %%
# now view the last 10

data.tail(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5671           FDA01        15.00              reg         0.054463
# 5672           NCH42         6.86          Low Fat         0.036594
# 5673           FDF46         7.07          Low Fat         0.094053
# 5674           DRL35        15.70          Low Fat         0.030704
# 5675           FDW46        13.00          Regular         0.070411
# 5676           FDB58        10.50          Regular         0.013496
# 5677           FDD47         7.60          Regular         0.142991
# 5678           NCO17        10.00          Low Fat         0.073529
# 5679           FDJ26        15.30          Regular         0.000000
# 5680           FDU37         9.50          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5671              Canned   59.5904            OUT049
# 5672           Household  231.1010            OUT049
# 5673         Snack Foods  116.0834            OUT018
# ...

# %%
# View the names of the columns

data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
# view data from a single column

data["Item_Weight"]
# Out:
# 0       20.750
# 1        8.300
# 2       14.600
# 3        7.315
# 4          NaN
#          ...
# 5676    10.500
# 5677     7.600
# 5678    10.000
# 5679    15.300
# 5680     9.500
# Name: Item_Weight, Length: 5681, dtype: float64

# %%
# selecting morethan one column

data[['Item_Fat_Content', 'Item_Visibility', 'Item_Type']]
# Out:
#      Item_Fat_Content  Item_Visibility           Item_Type
# 0             Low Fat         0.007565         Snack Foods
# 1                 reg         0.038428               Dairy
# 2             Low Fat         0.099575              Others
# 3             Low Fat         0.015388         Snack Foods
# 4             Regular         0.118599               Dairy
# ...               ...              ...                 ...
# 5676          Regular         0.013496         Snack Foods
# 5677          Regular         0.142991       Starchy Foods
# 5678          Low Fat         0.073529  Health and Hygiene
# 5679          Regular         0.000000              Canned
# 5680          Regular         0.104720              Canned
#
# [5681 rows x 3 columns]
