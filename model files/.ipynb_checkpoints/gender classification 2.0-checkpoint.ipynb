# %% [markdown]
# # **Changing the number of hidden layers in FC layers**
#
# ## 1. Loading data
# ## 2. Pre-processing the data
# ## 3. creating training and validation set
# ## 4. Defining the architecture
# ## 5. Compiling the model
# ## 6. Training the model
# ## 7. Evaluating model performance

# %%
# import necessary libraries and function

import numpy as np
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.layers import Dense, InputLayer
from keras.models import Sequential
from sklearn.model_selection import train_test_split

# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB 660.6 kB/s eta 0:00:59
#    ---------------------------------------- 0.2/38.6 MB 2.5 MB/s eta 0:00:16
#     --------------------------------------- 0.6/38.6 MB 4.8 MB/s eta 0:00:09
#     --------------------------------------- 0.9/38.6 MB 5.6 MB/s eta 0:00:07
#     --------------------------------------- 0.9/38.6 MB 5.6 MB/s eta 0:00:07
#    - -------------------------------------- 1.1/38.6 MB 4.0 MB/s eta 0:00:10
#    - -------------------------------------- 1.6/38.6 MB 5.1 MB/s eta 0:00:08
#    -- ------------------------------------- 2.3/38.6 MB 6.4 MB/s eta 0:00:06
#    --- ------------------------------------ 3.1/38.6 MB 7.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 3.9/38.6 MB 8.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.7/38.6 MB 9.3 MB/s eta 0:00:04
# ...

# %%
pip install imutils
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25855 sha256=9e2762058b2f4e109828a2f5d6f31b94c00b733e29e0c8dbb0139ddc4141e67f
#   Stored in directory: c:\users\staff\appdata\local\pip\cache\wheels\31\d0\2c\87ce38f6052879e5b7b18f0f8b4a10ad2a9d210e908d449f16
# Successfully built imutils
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import os
from imutils import paths

#load all image paths using the imutils library
imagePaths = list(paths.list_images('C:/Users/Staff/machine learning model/data files/gender classification model/images'))

# %%
# print the image paths
imagePaths
# Out:
# ['C:/Users/Staff/machine learning model/data files/gender classification model/images\\000001.jpg',
#  'C:/Users/Staff/machine learning model/data files/gender classification model/images\\000002.jpg',
#  'C:/Users/Staff/machine learning model/data files/gender classification model/images\\000003.jpg',
#  'C:/Users/Staff/machine learning model/data files/gender classification model/images\\000004.jpg',
#  'C:/Users/Staff/machine learning model/data files/gender classification model/images\\000005.jpg',
#  'C:/Users/Staff/machine learning model/data files/gender classification model/images\\000006.jpg',
#  'C:/Users/Staff/machine learning model/data files/gender classification model/images\\000007.jpg',
#  'C:/Users/Staff/machine learning model/data files/gender classification model/images\\000008.jpg',
#  'C:/Users/Staff/machine learning model/data files/gender classification model/images\\000009.jpg',
# ...

# %%
# Now we collecting the images and displaying them

for imagePath in imagePaths:
    image = cv2.imread(imagePath)
    cv2.imshow("Frame", image)
    cv2.waitKey()
cv2.destroyAllWindows()

# %%
data = pd.read_csv('Users/Staff/machine learning model/data files/gender classification model/test.csv')
